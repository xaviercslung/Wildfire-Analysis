# %%
import pandas as pd
import sqlite3
import datetime
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn import metrics
from sklearn import preprocessing
# %matplotlib inline

# %%
# Let's clean the data
data = sqlite3.connect("./data/FPA_FOD_20170508.sqlite")
test = pd.read_sql_query("SELECT * FROM 'fires'",data)
wf = pd.read_sql_query("SELECT FIRE_YEAR,STAT_CAUSE_DESCR,LATITUDE,LONGITUDE,STATE,DISCOVERY_DATE,FIRE_SIZE,FIPS_NAME FROM 'Fires'", data)

# %%
wf['DISCOVERY_DATE'] = pd.to_datetime(wf['DISCOVERY_DATE'] - pd.Timestamp(0).to_julian_date(), unit='D')
wf['DISCOVERY_DATE']
# Out:
# 0         2005-02-02
# 1         2004-05-12
# 2         2004-05-31
# 3         2004-06-28
# 4         2004-06-28
#              ...
# 1880460   2015-09-26
# 1880461   2015-10-05
# 1880462   2015-05-02
# 1880463   2015-10-14
# 1880464   2015-03-14
# Name: DISCOVERY_DATE, Length: 1880465, dtype: datetime64[ns]

# %%
wf['MONTH'] = wf['DISCOVERY_DATE'].dt.month
wf.head()
# Out:
#    FIRE_YEAR STAT_CAUSE_DESCR   LATITUDE   LONGITUDE STATE DISCOVERY_DATE  \
# 0       2005    Miscellaneous  40.036944 -121.005833    CA     2005-02-02
# 1       2004        Lightning  38.933056 -120.404444    CA     2004-05-12
# 2       2004   Debris Burning  38.984167 -120.735556    CA     2004-05-31
# 3       2004        Lightning  38.559167 -119.913333    CA     2004-06-28
# 4       2004        Lightning  38.559167 -119.933056    CA     2004-06-28
#
#    FIRE_SIZE  FIPS_NAME  MONTH
# 0       0.10     Plumas      2
# 1       0.25     Placer      5
# 2       0.10  El Dorado      5
# 3       0.10     Alpine      6
# 4       0.10     Alpine      6

# %%
wf['DAY'] = wf['DISCOVERY_DATE'].dt.day
wf.head()
# Out:
#    FIRE_YEAR STAT_CAUSE_DESCR   LATITUDE   LONGITUDE STATE DISCOVERY_DATE  \
# 0       2005    Miscellaneous  40.036944 -121.005833    CA     2005-02-02
# 1       2004        Lightning  38.933056 -120.404444    CA     2004-05-12
# 2       2004   Debris Burning  38.984167 -120.735556    CA     2004-05-31
# 3       2004        Lightning  38.559167 -119.913333    CA     2004-06-28
# 4       2004        Lightning  38.559167 -119.933056    CA     2004-06-28
#
#    FIRE_SIZE  FIPS_NAME  MONTH  DAY
# 0       0.10     Plumas      2    2
# 1       0.25     Placer      5   12
# 2       0.10  El Dorado      5   31
# 3       0.10     Alpine      6   28
# 4       0.10     Alpine      6   28

# %%
len(wf)
# Out:
# 1880465

# %%
# wf = wf[wf['STATE'] == 'CA']
# wf['STATE'].unique()

# %%
wf.columns= wf.columns.str.lower()
wf.head()
# Out:
#    fire_year stat_cause_descr   latitude   longitude state discovery_date  \
# 0       2005    Miscellaneous  40.036944 -121.005833    CA     2005-02-02
# 1       2004        Lightning  38.933056 -120.404444    CA     2004-05-12
# 2       2004   Debris Burning  38.984167 -120.735556    CA     2004-05-31
# 3       2004        Lightning  38.559167 -119.913333    CA     2004-06-28
# 4       2004        Lightning  38.559167 -119.933056    CA     2004-06-28
#
#    fire_size  fips_name  month  day
# 0       0.10     Plumas      2    2
# 1       0.25     Placer      5   12
# 2       0.10  El Dorado      5   31
# 3       0.10     Alpine      6   28
# 4       0.10     Alpine      6   28

# %%
wf = wf.rename(columns={"fire_year":"year","fips_name":"county","stat_cause_descr":"cause"})
wf.head()
# Out:
#    year           cause   latitude   longitude state discovery_date  \
# 0  2005   Miscellaneous  40.036944 -121.005833    CA     2005-02-02
# 1  2004       Lightning  38.933056 -120.404444    CA     2004-05-12
# 2  2004  Debris Burning  38.984167 -120.735556    CA     2004-05-31
# 3  2004       Lightning  38.559167 -119.913333    CA     2004-06-28
# 4  2004       Lightning  38.559167 -119.933056    CA     2004-06-28
#
#    fire_size     county  month  day
# 0       0.10     Plumas      2    2
# 1       0.25     Placer      5   12
# 2       0.10  El Dorado      5   31
# 3       0.10     Alpine      6   28
# 4       0.10     Alpine      6   28

# %%
wf.to_csv('./data/wildfre_cleaned.csv',index=False)

# %%
wf = pd.read_csv('./data/wildfre_cleaned.csv')

# %%
wf.describe()
# Out:
#                year      latitude     longitude     fire_size         month  \
# count  1.880465e+06  1.880465e+06  1.880465e+06  1.880465e+06  1.880465e+06
# mean   2.003710e+03  3.678121e+01 -9.570494e+01  7.452016e+01  5.930107e+00
# std    6.663099e+00  6.139031e+00  1.671694e+01  2.497598e+03  2.954900e+00
# min    1.992000e+03  1.793972e+01 -1.788026e+02  1.000000e-05  1.000000e+00
# 25%    1.998000e+03  3.281860e+01 -1.103635e+02  1.000000e-01  3.000000e+00
# 50%    2.004000e+03  3.545250e+01 -9.204304e+01  1.000000e+00  6.000000e+00
# 75%    2.009000e+03  4.082720e+01 -8.229760e+01  3.300000e+00  8.000000e+00
# max    2.015000e+03  7.033060e+01 -6.525694e+01  6.069450e+05  1.200000e+01
#
#                 day
# count  1.880465e+06
# mean   1.551281e+01
# std    8.798520e+00
# min    1.000000e+00
# 25%    8.000000e+00
# 50%    1.500000e+01
# 75%    2.300000e+01
# max    3.100000e+01

# %%
wf.isna().sum()
# Out:
# year                   0
# cause                  0
# latitude               0
# longitude              0
# state                  0
# discovery_date         0
# fire_size              0
# county            678148
# month                  0
# day                    0
# dtype: int64

# %%
wf = wf.dropna().copy()

# %%
states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

# %%
len(states)
# Out:
# 51

# %%
wf = wf[wf.state.isin(states)]

# %%
slist = wf.state.to_list()

# %%
set(states).difference(slist)
# Out:
# {'DC'}

# %%
fire_map = gpd.read_file('./data/tl_2019_us_state.shp')

# %%
fire_map = fire_map[fire_map.STUSPS.isin(states)]

# %%
fire_map.head()
# Out:
#   REGION DIVISION STATEFP   STATENS GEOID STUSPS           NAME LSAD  MTFCC  \
# 0      3        5      54  01779805    54     WV  West Virginia   00  G4000
# 1      3        5      12  00294478    12     FL        Florida   00  G4000
# 2      2        3      17  01779784    17     IL       Illinois   00  G4000
# 3      2        4      27  00662849    27     MN      Minnesota   00  G4000
# 4      3        5      24  01714934    24     MD       Maryland   00  G4000
#
#   FUNCSTAT         ALAND       AWATER     INTPTLAT      INTPTLON  \
# 0        A   62266231560    489271086  +38.6472854  -080.6183274
# 1        A  138947364717  31362872853  +28.4574302  -082.4091477
# 2        A  143779863817   6215723896  +40.1028754  -089.1526108
# 3        A  206230065476  18942261495  +46.3159573  -094.1996043
# 4        A   25151726296   6979340970  +38.9466584  -076.6744939
#
#                                             geometry
# 0  POLYGON ((-81.74725 39.09538, -81.74635 39.096...
# 1  MULTIPOLYGON (((-86.38865 30.99418, -86.38385 ...
# 2  POLYGON ((-91.18529 40.63780, -91.17510 40.643...
# 3  POLYGON ((-96.78438 46.63050, -96.78434 46.630...
# 4  POLYGON ((-77.45881 39.22027, -77.45866 39.220...

# %%
# wf=wf[wf['year'] == 2015]

# %%
# geometry = [Point(xy) for xy in zip(wf['longitude'],wf['latitude'])]
# geometry[:3]

# %%
# crs = {'init':'epsg:4326'}
# geo_df = gpd.GeoDataFrame(wf,crs=crs,geometry=geometry)
# geo_df.head()

# %%
# fig,ax = plt.subplots(figsize=(40,40))
# fire_map.plot(ax=ax,color='grey')
# geo_df.plot(ax=ax,markersize = 0.1, color='red',marker='o')

# %%
# geo_df.state.unique()

# %%
wf.head()
# Out:
#    year           cause   latitude   longitude state discovery_date  \
# 0  2005   Miscellaneous  40.036944 -121.005833    CA     2005-02-02
# 1  2004       Lightning  38.933056 -120.404444    CA     2004-05-12
# 2  2004  Debris Burning  38.984167 -120.735556    CA     2004-05-31
# 3  2004       Lightning  38.559167 -119.913333    CA     2004-06-28
# 4  2004       Lightning  38.559167 -119.933056    CA     2004-06-28
#
#    fire_size     county  month  day
# 0       0.10     Plumas      2    2
# 1       0.25     Placer      5   12
# 2       0.10  El Dorado      5   31
# 3       0.10     Alpine      6   28
# 4       0.10     Alpine      6   28

# %%
wf_causes = wf.copy()

# %%
wf_causes = wf_causes[['county','cause','state']].groupby(['county','cause','state']).size().reset_index()
wf_causes.rename(columns={0:'count'},inplace=True)
wf_causes
# Out:
#           county              cause state  count
# 0      Abbeville              Arson    SC    180
# 1      Abbeville           Campfire    SC      9
# 2      Abbeville           Children    SC     16
# 3      Abbeville     Debris Burning    SC    181
# 4      Abbeville      Equipment Use    SC     64
# ...          ...                ...   ...    ...
# 22905    Ziebach              Arson    SD      1
# 22906    Ziebach           Campfire    SD      1
# 22907    Ziebach      Equipment Use    SD      2
# 22908    Ziebach      Miscellaneous    SD     17
# 22909    Ziebach  Missing/Undefined    SD      1
#
# [22910 rows x 4 columns]

# %%
len(wf_causes.county.unique())
# Out:
# 1694

# %%
wf_causes=pd.pivot_table(wf_causes,index=['county','state'],columns='cause',values='count',fill_value=0)

# %%
wf_causes
# Out:
# cause            Arson  Campfire  Children  Debris Burning  Equipment Use  \
# county    state
# Abbeville SC       180         9        16             181             64
# Acadia    LA         4         0         0               0              0
# Accomack  VA        68         0         2              30             11
# Ada       ID       384        29         4               8            327
# Adair     IA         0         0         1               4              0
# ...                ...       ...       ...             ...            ...
# Yuma      AZ         6        63         1              19             19
#           CO         0         0         0               1              3
# Zapata    TX         1         1         8              20             29
# Zavala    TX        12         1        13              44             11
# Ziebach   SD         1         1         0               0              2
#
# cause            Fireworks  Lightning  Miscellaneous  Missing/Undefined  \
# county    state
# Abbeville SC             2         17             58                311
# Acadia    LA             0          0              0                  4
# Accomack  VA             0          6              6                  3
# Ada       ID            26        292            159                 76
# Adair     IA             0          0              0                 40
# ...                    ...        ...            ...                ...
# Yuma      AZ             2         18            144                 46
#           CO             1          6             36                  9
# Zapata    TX             0          1            126                  0
# Zavala    TX             0          1             66                  0
# Ziebach   SD             0          0             17                  1
#
# cause            Powerline  Railroad  Smoking  Structure
# county    state
# Abbeville SC             8         4       26          3
# Acadia    LA             0         0        0          0
# Accomack  VA             0         1        2          3
# Ada       ID            22        12        4          0
# Adair     IA             0         0        0          0
# ...                    ...       ...      ...        ...
# Yuma      AZ             1         1        2          0
#           CO             0         0        3          0
# Zapata    TX             5         0        1          0
# Zavala    TX             2         0        5          0
# Ziebach   SD             0         0        0          0
#
# [2794 rows x 13 columns]

# %%
#Normalize the data
total_causes = wf_causes.sum(axis=1)
wf_nor=wf_causes.div(wf_causes.sum(axis=1), axis=0)

# %%
wf_nor=wf_nor.loc[total_causes>100]
wf_nor
# Out:
# cause               Arson  Campfire  Children  Debris Burning  Equipment Use  \
# county    state
# Abbeville SC     0.204778  0.010239  0.018203        0.205916       0.072810
# Accomack  VA     0.515152  0.000000  0.015152        0.227273       0.083333
# Ada       ID     0.285927  0.021593  0.002978        0.005957       0.243485
# Adair     OK     0.297753  0.001124  0.001124        0.089513       0.007116
# Adams     CO     0.031873  0.007968  0.001992        0.025896       0.033865
# ...                   ...       ...       ...             ...            ...
# Young     TX     0.018801  0.004700  0.008226        0.143361       0.294947
# Yuba      CA     0.088725  0.012939  0.022181        0.136784       0.155268
# Yuma      AZ     0.018634  0.195652  0.003106        0.059006       0.059006
# Zapata    TX     0.005208  0.005208  0.041667        0.104167       0.151042
# Zavala    TX     0.077419  0.006452  0.083871        0.283871       0.070968
#
# cause            Fireworks  Lightning  Miscellaneous  Missing/Undefined  \
# county    state
# Abbeville SC      0.002275   0.019340       0.065984           0.353811
# Accomack  VA      0.000000   0.045455       0.045455           0.022727
# Ada       ID      0.019360   0.217424       0.118392           0.056590
# Adair     OK      0.000000   0.000375       0.026966           0.575281
# Adams     CO      0.023904   0.027888       0.814741           0.005976
# ...                    ...        ...            ...                ...
# Young     TX      0.001175   0.045828       0.378378           0.001175
# Yuba      CA      0.000000   0.035120       0.240296           0.288355
# Yuma      AZ      0.006211   0.055901       0.447205           0.142857
# Zapata    TX      0.000000   0.005208       0.656250           0.000000
# Zavala    TX      0.000000   0.006452       0.425806           0.000000
#
# cause            Powerline  Railroad   Smoking  Structure
# county    state
# Abbeville SC      0.009101  0.004551  0.029579   0.003413
# Accomack  VA      0.000000  0.007576  0.015152   0.022727
# Ada       ID      0.016381  0.008935  0.002978   0.000000
# Adair     OK      0.000000  0.000749  0.000000   0.000000
# Adams     CO      0.000000  0.000000  0.025896   0.000000
# ...                    ...       ...       ...        ...
# Young     TX      0.084606  0.000000  0.018801   0.000000
# Yuba      CA      0.005545  0.000000  0.014787   0.000000
# Yuma      AZ      0.003106  0.003106  0.006211   0.000000
# Zapata    TX      0.026042  0.000000  0.005208   0.000000
# Zavala    TX      0.012903  0.000000  0.032258   0.000000
#
# [1698 rows x 13 columns]

# %%
scaler = preprocessing.StandardScaler().fit(wf_nor)
data_nor=scaler.transform(wf_nor)
data_nor
# Out:
# array([[ 0.52146148, -0.524989  , -0.19778049, ..., -0.35021659,
#          0.04788905,  0.11635998],
#        [ 2.73148066, -0.68732542, -0.2867107 , ..., -0.27944899,
#         -0.41797   ,  2.98449048],
#        [ 1.09928351, -0.34496439, -0.64153257, ..., -0.24764678,
#         -0.8110341 , -0.39045826],
#        ...,
#        [-0.80398467,  2.41471193, -0.63782542, ..., -0.38402064,
#         -0.70664932, -0.39045826],
#        [-0.8995791 , -0.60474804,  0.48615314, ..., -0.45667042,
#         -0.73903079, -0.39045826],
#        [-0.3853992 , -0.58503602,  1.71632444, ..., -0.45667042,
#          0.13439265, -0.39045826]])

# %%
data_nor.shape
# Out:
# (1698, 13)

# %%
tup_list=wf_nor.index

# %%
len(tup_list)
# Out:
# 1698

# %%
actual_label=[]
for x in range(len(tup_list)):
    temp = tup_list[x][0]
    actual_label.append(temp)

# %%
def ACC_out(predict,actual):
    a = 1.0*sum(predict==actual)/len(predict)*100
    print('ACC = %.2f'%(a) + '%')
    return round(a,2)

# %%
log_reg = LogisticRegression(max_iter = 140)
X = data_nor[:,:]
log_reg.fit(X,actual_label)
# predict_label = log_reg.predict(X)
# Out:
# LogisticRegression(max_iter=140)

# %%
# ACC_out(predict_label,actual_label)

# %%
# r_num = round(len(data_nor)*0.75)

# %%
# test_set = X[:r_num]
# actual_label2 = actual_label[:r_num]

# %%
# predict_label2 = log_reg.predict(test_set)

# %%
# ACC_out(predict_label2,actual_label2)

# %%
import random
def reg_model_test(model,actual,rand_min,rand_max,rand_num,X):
    random_list = random.sample(range(rand_min,rand_max), rand_num)
    temp_num = 0
    temp_list =[]
    for i in random_list:
        actual_temp=[]
        test_set = X[:i]
        actual_temp = actual[:i]
        predict = log_reg.predict(test_set)
        print(('Random silce of: {}'.format(i)))
        c = ACC_out(predict,actual_temp)
        temp_list.append(c)
        print()
    avg = sum(temp_list)/len(temp_list)
    print('number of iteration:' + str(rand_num) + ' ,Average:' + str(round(avg,2)) + '%')
    print()

# %%
reg_model_test(log_reg,actual_label,50,90,40,X)
# Out:
# Random silce of: 50
# ACC = 72.00%
#
# Random silce of: 56
# ACC = 71.43%
#
# Random silce of: 70
# ACC = 75.71%
#
# Random silce of: 80
# ACC = 78.75%
#
# Random silce of: 52
# ACC = 71.15%
#
# Random silce of: 71
# ACC = 76.06%
#
# Random silce of: 77
# ACC = 77.92%
#
# Random silce of: 61
# ACC = 73.77%
#
# Random silce of: 58
# ACC = 72.41%
#
# Random silce of: 82
# ACC = 79.27%
#
# Random silce of: 72
# ACC = 76.39%
#
# Random silce of: 59
# ACC = 72.88%
#
# Random silce of: 85
# ACC = 78.82%
#
# Random silce of: 88
# ACC = 79.55%
#
# Random silce of: 60
# ACC = 73.33%
#
# Random silce of: 63
# ACC = 74.60%
#
# Random silce of: 84
# ACC = 78.57%
#
# Random silce of: 83
# ACC = 78.31%
#
# Random silce of: 75
# ACC = 77.33%
#
# Random silce of: 55
# ACC = 70.91%
#
# Random silce of: 62
# ACC = 74.19%
#
# Random silce of: 87
# ACC = 79.31%
#
# Random silce of: 66
# ACC = 75.76%
#
# Random silce of: 68
# ACC = 76.47%
#
# Random silce of: 89
# ACC = 79.78%
#
# Random silce of: 86
# ACC = 79.07%
#
# Random silce of: 53
# ACC = 71.70%
#
# Random silce of: 51
# ACC = 70.59%
#
# Random silce of: 81
# ACC = 79.01%
#
# Random silce of: 69
# ACC = 76.81%
#
# Random silce of: 73
# ACC = 76.71%
#
# Random silce of: 65
# ACC = 75.38%
#
# Random silce of: 74
# ACC = 77.03%
#
# Random silce of: 79
# ACC = 78.48%
#
# Random silce of: 64
# ACC = 75.00%
#
# Random silce of: 67
# ACC = 76.12%
#
# Random silce of: 76
# ACC = 77.63%
#
# Random silce of: 57
# ACC = 71.93%
#
# Random silce of: 78
# ACC = 78.21%
#
# Random silce of: 54
# ACC = 72.22%
#
# number of iteration:40 ,Average:75.76%
